# %%
import numpy as np
import pandas as pd
import torch
import sqlite3

# %%
fdb = sqlite3.connect("data/FDB.db")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fdb = sqlite3.connect("data/FDB.db")
#
# OperationalError: unable to open database file
