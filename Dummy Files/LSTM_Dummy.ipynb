# %% [markdown]
# <a href="https://colab.research.google.com/github/miretteamin/NeuroStock/blob/master/Dummy%20Files/LSTM_Dummy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import sqlite3
from google.colab import drive
import sqlite3
import json

# %%
drive.mount("drive")
# Out:
# Mounted at drive

# %%
con = sqlite3.connect("/content/drive/MyDrive/Our GP folder/Data/FDB/FDB.db")

# %%
sql_query = """SELECT name FROM sqlite_master  
  WHERE type='table';"""
cursor =  con.cursor()

cursor.execute(sql_query)
tables = [ x[0]  for x in cursor.fetchall()]

# %%
tables
# Out:
# ['us_equities_news_dataset', 'nasdaq_screener', 'stockHistory']
